# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import Tokenizer, HashingTF, IDF
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import Normalizer
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator

# %%
spark = SparkSession.builder.appName("LabEndsemPrac").getOrCreate()

# %%
df = spark.read.csv("synthetic_crop_yield.csv", 
                    sep=",", 
                    quote='"',
                    inferSchema=True,
                    header=True)
df.show(5)
df.printSchema()
# Out:
# +-------+-------+------+------+------------------+------------------+------------------+
# |user_id|crop_id|rating| state|      soil_quality|          rainfall|             yield|
# +-------+-------+------+------+------------------+------------------+------------------+
# |     39|      1|     5|State2|1.4473952495864468|  97.8329737705031| 1333.412487228435|
# |     29|      6|     5|State4|0.8373401410170235| 85.79430013239207|1024.3014593681485|
# |     15|      6|     1|State4|1.2249811699240525|102.21311367797993|1101.4908676573082|
# |     43|     16|     2|State1| 1.038813009039619| 101.1548262958734|1167.1508027715001|
# |      8|      4|     4|State4|0.5606289260664682| 115.2785995477906|1026.8081772466048|
# +-------+-------+------+------+------------------+------------------+------------------+
# only showing top 5 rows
#
# root
#  |-- user_id: integer (nullable = true)
#  |-- crop_id: integer (nullable = true)
#  |-- rating: integer (nullable = true)
#  |-- state: string (nullable = true)
#  |-- soil_quality: double (nullable = true)
#  |-- rainfall: double (nullable = true)
#  |-- yield: double (nullable = true)

# %%
filtered_df = df.filter(df["yield"]>1000).select("state","crop_id","yield")

filtered_df.show()
# Out:
# +------+-------+------------------+
# | state|crop_id|             yield|
# +------+-------+------------------+
# |State2|      1| 1333.412487228435|
# |State4|      6|1024.3014593681485|
# |State4|      6|1101.4908676573082|
# |State1|     16|1167.1508027715001|
# |State4|      4|1026.8081772466048|
# |State1|     11|1048.1265488050308|
# |State4|      8| 1121.091683364107|
# |State2|      5| 1014.178130564413|
# |State2|      6|1116.0197683270414|
# |State3|      2|1108.6912921908213|
# |State3|      4|1109.4283350120954|
# |State4|      6|  1113.24535297919|
# |State1|     17|1060.2047208327124|
# |State4|     19|1043.9593469996205|
# |State1|      2| 1073.129717331181|
# |State4|     19|1163.3677419264504|
# |State4|     20|1118.9529829553862|
# |State4|      1|1167.2442157750004|
# |State4|     17|1028.3101558158687|
# |State3|     15|1085.7840796361977|
# +------+-------+------------------+
# only showing top 20 rows

# %%
df = df.na.drop()
df = df.na.fill({"yield": 0})

df.show()
# Out:
# +-------+-------+------+------+------------------+------------------+------------------+
# |user_id|crop_id|rating| state|      soil_quality|          rainfall|             yield|
# +-------+-------+------+------+------------------+------------------+------------------+
# |     39|      1|     5|State2|1.4473952495864468|  97.8329737705031| 1333.412487228435|
# |     29|      6|     5|State4|0.8373401410170235| 85.79430013239207|1024.3014593681485|
# |     15|      6|     1|State4|1.2249811699240525|102.21311367797993|1101.4908676573082|
# |     43|     16|     2|State1| 1.038813009039619| 101.1548262958734|1167.1508027715001|
# |      8|      4|     4|State4|0.5606289260664682| 115.2785995477906|1026.8081772466048|
# |     21|     11|     2|State1|1.1899997373089435| 104.3671646235406|1048.1265488050308|
# |     39|      9|     2|State3|1.1900965582378435| 93.75772216207828| 782.6749646092585|
# |     19|      3|     1|State3| 1.430606804846537|106.16273806649025|  820.776994312683|
# |     23|     19|     1|State4|0.9973124461689724|  84.5470897015309| 810.4370489743106|
# |     11|      8|     1|State4|0.7302509207105147| 99.42788967963524| 1121.091683364107|
# |     11|      5|     1|State2|0.5445638234486792|104.79101850393371| 1014.178130564413|
# |     24|      4|     5|State4|0.9156421866859057| 101.9397639722519| 820.7936872468824|
# |     36|      6|     1|State2|0.8019167000775018|106.22597642403976|1116.0197683270414|
# |     40|      2|     5|State3|1.2610883060238756| 90.33930976430813|1108.6912921908213|
# |     24|     20|     5|State3|0.8542677648410466|117.28047104214274|  861.006801740127|
# |      3|     11|     1|State1| 1.449071196314844| 127.3325342409356| 994.4344910741453|
# |     22|      4|     3|State3|1.4623102029877844| 75.95985782712108|1109.4283350120954|
# |      2|     15|     4|State2| 1.120908590217708| 81.76603006068628| 828.3289291761153|
# |     24|      6|     2|State4|1.4286602870148828|100.64624512036578|  1113.24535297919|
# |     44|     17|     5|State1|1.2608543445144957| 96.15173529170688|1060.2047208327124|
# +-------+-------+------+------+------------------+------------------+------------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol="state", outputCol="massive")
df = indexer.fit(df).transform(df)

df.show()
# Out:
# +-------+-------+------+------+------------------+------------------+------------------+-------------+-------+
# |user_id|crop_id|rating| state|      soil_quality|          rainfall|             yield|categoryIndex|massive|
# +-------+-------+------+------+------------------+------------------+------------------+-------------+-------+
# |     39|      1|     5|State2|1.4473952495864468|  97.8329737705031| 1333.412487228435|          3.0|    3.0|
# |     29|      6|     5|State4|0.8373401410170235| 85.79430013239207|1024.3014593681485|          2.0|    2.0|
# |     15|      6|     1|State4|1.2249811699240525|102.21311367797993|1101.4908676573082|          2.0|    2.0|
# |     43|     16|     2|State1| 1.038813009039619| 101.1548262958734|1167.1508027715001|          0.0|    0.0|
# |      8|      4|     4|State4|0.5606289260664682| 115.2785995477906|1026.8081772466048|          2.0|    2.0|
# |     21|     11|     2|State1|1.1899997373089435| 104.3671646235406|1048.1265488050308|          0.0|    0.0|
# |     39|      9|     2|State3|1.1900965582378435| 93.75772216207828| 782.6749646092585|          1.0|    1.0|
# |     19|      3|     1|State3| 1.430606804846537|106.16273806649025|  820.776994312683|          1.0|    1.0|
# |     23|     19|     1|State4|0.9973124461689724|  84.5470897015309| 810.4370489743106|          2.0|    2.0|
# |     11|      8|     1|State4|0.7302509207105147| 99.42788967963524| 1121.091683364107|          2.0|    2.0|
# |     11|      5|     1|State2|0.5445638234486792|104.79101850393371| 1014.178130564413|          3.0|    3.0|
# |     24|      4|     5|State4|0.9156421866859057| 101.9397639722519| 820.7936872468824|          2.0|    2.0|
# |     36|      6|     1|State2|0.8019167000775018|106.22597642403976|1116.0197683270414|          3.0|    3.0|
# |     40|      2|     5|State3|1.2610883060238756| 90.33930976430813|1108.6912921908213|          1.0|    1.0|
# |     24|     20|     5|State3|0.8542677648410466|117.28047104214274|  861.006801740127|          1.0|    1.0|
# |      3|     11|     1|State1| 1.449071196314844| 127.3325342409356| 994.4344910741453|          0.0|    0.0|
# |     22|      4|     3|State3|1.4623102029877844| 75.95985782712108|1109.4283350120954|          1.0|    1.0|
# |      2|     15|     4|State2| 1.120908590217708| 81.76603006068628| 828.3289291761153|          3.0|    3.0|
# |     24|      6|     2|State4|1.4286602870148828|100.64624512036578|  1113.24535297919|          2.0|    2.0|
# |     44|     17|     5|State1|1.2608543445144957| 96.15173529170688|1060.2047208327124|          0.0|    0.0|
# +-------+-------+------+------+------------------+------------------+------------------+-------------+-------+
# only showing top 20 rows

# %%
train, test = df.randomSplit([0.7, 0.3], seed=1234)

# %%
from pyspark.ml.recommendation import ALS

als = ALS(userCol="user_id", itemCol="crop_id", ratingCol="rating", rank=10)
model = als.fit(train)

# Predicting on test data
predictions = model.transform(test)

# %%
predictions.show()
# Out:
# +-------+-------+------+------+------------------+------------------+------------------+-------------+-------+----------+
# |user_id|crop_id|rating| state|      soil_quality|          rainfall|             yield|categoryIndex|massive|prediction|
# +-------+-------+------+------+------------------+------------------+------------------+-------------+-------+----------+
# |      1|      1|     1|State4|0.8526026059288582| 77.97495157698857| 1028.288102584671|          2.0|    2.0| 2.9484446|
# |      1|      1|     4|State1|1.0298812610885262| 96.13016042239097|1123.2451557587103|          0.0|    0.0| 2.9484446|
# |      1|      5|     1|State4|1.2894321941951912| 93.86325079517123| 1085.826572304459|          2.0|    2.0| 2.7901173|
# |      1|     17|     2|State3| 1.214641274908724| 95.10319166423974|1196.3561893911606|          1.0|    1.0| 3.7873878|
# |      2|      1|     2|State4|1.1011026956243284|  118.865413333656| 946.8480362574217|          2.0|    2.0| 2.7820675|
# |      2|      1|     5|State4|1.1002814605280369|111.76249666326338| 785.3121761785023|          2.0|    2.0| 2.7820675|
# |      2|      2|     2|State1|  0.95859794351384|120.88817880588937| 1073.129717331181|          0.0|    0.0| 2.1186762|
# |      2|      2|     5|State4|0.8119840203264185| 104.5759320844775| 996.4071423085687|          2.0|    2.0| 2.1186762|
# |      2|      4|     5|State3|0.8040302724479996| 87.78243683857585| 1030.786038619801|          1.0|    1.0|  2.948594|
# |      2|     11|     4|State1|0.8336067890290432|  97.9549247947827| 639.2066718610645|          0.0|    0.0| 3.6711874|
# |      2|     11|     4|State1|1.2844208580034175|113.45461657930711|1223.9580701480375|          0.0|    0.0| 3.6711874|
# |      2|     15|     1|State1|0.9162180588453493|  88.0867450207835|1089.9216495419919|          0.0|    0.0|  4.046804|
# |      3|      1|     1|State2|0.5708915758912854|109.92684182036102| 1064.913506974828|          3.0|    3.0| 3.4317157|
# |      3|      2|     3|State3|0.7676007988617075|108.62549552663528|1012.8461667406654|          1.0|    1.0| 2.4956193|
# |      3|      7|     2|State4|1.2805560268872138|112.83604646762836| 643.3557037432405|          2.0|    2.0| 3.0210528|
# |      3|     12|     4|State1| 1.453020021178899|105.66421759493409| 515.3907001996932|          0.0|    0.0| 2.9061909|
# |      3|     14|     4|State4| 1.059578854465342| 94.87618117736908| 713.4806740416918|          2.0|    2.0|  1.730526|
# |      3|     15|     1|State3|0.8974481568990916|103.74376842683753|1349.4752719419812|          1.0|    1.0| 1.3348461|
# |      3|     18|     5|State1|1.1390321589149208|111.38635593082596|1255.0186043763397|          0.0|    0.0| 1.6007369|
# |      3|     19|     4|State3|1.1321594991864574|  85.4061867101313|1009.4143373615775|          1.0|    1.0| 3.2481723|
# +-------+-------+------+------+------------------+------------------+------------------+-------------+-------+----------+
# only showing top 20 rows
